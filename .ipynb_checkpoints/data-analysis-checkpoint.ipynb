# %%
import numpy as np
import pandas as pd

# %%
df = df.drop(columns=['relator','registros', 'ano_registro', 'classe_motivo', 'aisp',  'linha'])

# %%
# Out:
#                                                     dia_semana  hora_fato  \
# consolidado
# A ARREGIMENTACAO DE ELEITOR OU A PROPAGANDA DE ...          71         71
# A DIVULGACAO DE QUALQUER ESPECIE DE PROPAGANDA ...          30         30
# A INCOLUMIDADE FISICA DO INDIVIDUO                           5          5
# A INVIOLABILIDADE DO DOMICILIO                               3          3
# A VIOLENCIA PATRIMONIAL, ENTENDIDA COMO QUALQUE...          17         17
# ...                                                        ...        ...
# VIOLENCIA FISICA, QUALQUER CONDUTA QUE OFENDA S...          88         88
# VIOLENCIA MORAL, QUALQUER CONDUTA QUE CONFIGURE...         129        129
# VIOLENCIA PSICOLOGICA                                      751        751
# VIOLENCIA SEXUAL, QUALQUER CONDUTA QUE A CONSTR...           3          3
# VOTAR OU TENTAR VOTAR MAIS DE UMA VEZ, OU EM LU...           2          2
#
# ...
